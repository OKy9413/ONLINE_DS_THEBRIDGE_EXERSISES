# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import random

# %% [markdown]
# # URL de la página de la que quieres extraer la tabla
# url = 'https://disfold.com/france/companies/?page2'
#
# # Envía una solicitud HTTP a la página
# response = requests.get(url)
#
# # Analiza el contenido HTML con BeautifulSoup
# soup = BeautifulSoup(response.text, 'html.parser')
#
# # Encuentra la tabla que quieres extraer
# table = soup.find('table', {'class': 'striped'})
#
# # Encuentra todas las filas de la tabla
# rows = table.find_all('tr')
#
# # Extrae los datos de cada fila
# deta = []
# for row in rows:
#     cols = row.find_all('td')
#     if len(cols) >= 2:  # Asegúrate de que haya al menos dos columnas
#         # Añade solo el texto del segundo 'td' de cada fila
#         deta.append(cols[1].get_text().strip())
#
# # Aquí tienes tus datos
# print(deta)

# %%
def get_companies(urls_paises = {
    "France": [
        "https://disfold.com/france/companies/?page=1",
        "https://disfold.com/france/companies/?page=2",
        "https://disfold.com/france/companies/?page=3",
        "https://disfold.com/france/companies/?page=4"
    ],
    "Germany": [
        "https://disfold.com/germany/companies/?page=1",
        "https://disfold.com/germany/companies/?page=2",
        "https://disfold.com/germany/companies/?page=3",
        "https://disfold.com/germany/companies/?page=4"
    ],
    "United-Kingdom": [
        "https://disfold.com/united-kingdom/companies/?page=1",
        "https://disfold.com/united-kingdom/companies/?page=2",
        "https://disfold.com/united-kingdom/companies/?page=3",
        "https://disfold.com/united-kingdom/companies/?page=4"
    ],
    "Spain": [
        "https://disfold.com/spain/companies/?page=1",
        "https://disfold.com/spain/companies/?page=2",
        "https://disfold.com/spain/companies/?page=3",
        "https://disfold.com/spain/companies/?page=4"
    ],
    "Italy": [
        "https://disfold.com/italy/companies/?page=1",
        "https://disfold.com/italy/companies/?page=2",
        "https://disfold.com/italy/companies/?page=3",
        "https://disfold.com/italy/companies/?page=4"
    ],
    "Ireland": [
        "https://disfold.com/ireland/companies/?page=1",
        "https://disfold.com/ireland/companies/?page=2"
    ]
} ):
    nombres_empresas = []
    paises_empresas = []

    for pais, urls in urls_paises.items():
        for url in urls:
            response = requests.get(url)
            soup = BeautifulSoup(response.text, 'html.parser')
            table = soup.find('table', {'class': 'striped'})
            rows = table.find_all('tr')

            for row in rows:
                cols = row.find_all('td')
                if len(cols) >= 2:
                    nombres_empresas.append(cols[1].get_text().strip())
                    paises_empresas.append(pais)
            
            time.sleep(1)  # Espera 1 segundo entre solicitudes

    return (nombres_empresas, paises_empresas)

# %%
companies = get_companies()

# %%
def comp_name(quantity, countries=None):
    # Si no se especifican países, se utilizan estos por defecto
    if countries is None:
        countries = ["Spain", "Italy", "Germany", "United-Kingdom", "Ireland", "France"]

    # Asumiendo que 'companies' es una tupla (lista_empresas, lista_paises)
    lista_empresas, lista_paises = companies

    # Filtrar las empresas por los países especificados
    empresas_filtradas = [(lista_empresas[i], lista_paises[i]) for i in range(len(lista_empresas)) if lista_paises[i] in countries]

    # Asegurarse de que la cantidad solicitada no sea mayor que la cantidad disponible
    quantity = min(quantity, len(empresas_filtradas))

    # Seleccionar aleatoriamente una cantidad determinada de empresas
    empresas_seleccionadas = random.sample(empresas_filtradas, quantity)

    # Crear y devolver un diccionario con los nombres de las empresas y sus países
    resultado = {nombre: pais for nombre, pais in empresas_seleccionadas}

    return resultado

# %%
# comp_name(1058)

# %%
name_comp = pd.read_csv('companies.csv', encoding = 'utf-8', delimiter=';')
name_comp.head()
name_comp['country'].unique()
# Out:
# array(['France', 'Germany', 'United Kingdom', 'Spain', 'Italy', 'Ireland'],
#       dtype=object)

# %%
# Asumiendo que companies es una tupla de dos listas (lista_empresas, lista_paises)
lista_empresas, lista_paises = companies

# Crear un DataFrame a partir de la tupla
df = pd.DataFrame({
    'company_name': lista_empresas,
    'country': lista_paises
})

# Guardar el DataFrame en un archivo CSV, separado por ';'
df.to_csv('companies.csv', sep=';', index=False, encoding='utf-8')

# %%
cities = {
    "Jerez de la Frontera": "Spain", "Madrid": "Spain", "Barcelona": "Spain",
    "Seville": "Spain", "Valencia": "Spain", "Bilbao": "Spain",
    "Malaga": "Spain", "Zaragoza": "Spain", "Murcia": "Spain", "Palma": "Spain",
    "Paris": "France", "Marseille": "France", "Lyon": "France",
    "Toulouse": "France", "Nice": "France", "Nantes": "France",
    "Strasbourg": "France", "Montpellier": "France", "Bordeaux": "France", "Lille": "France",
    "London": "United Kingdom", "Manchester": "United Kingdom", "Liverpool": "United Kingdom",
    "Edinburgh": "United Kingdom", "Glasgow": "United Kingdom", "Birmingham": "United Kingdom",
    "Leeds": "United Kingdom", "Bristol": "United Kingdom", "Sheffield": "United Kingdom", "Leicester": "United Kingdom",
    "Berlin": "Germany", "Munich": "Germany", "Frankfurt": "Germany",
    "Hamburg": "Germany", "Cologne": "Germany", "Stuttgart": "Germany",
    "Düsseldorf": "Germany", "Dortmund": "Germany", "Essen": "Germany", "Leipzig": "Germany",
    "Rome": "Italy", "Milan": "Italy", "Naples": "Italy",
    "Turin": "Italy", "Palermo": "Italy", "Genoa": "Italy",
    "Bologna": "Italy", "Florence": "Italy", "Bari": "Italy", "Catania": "Italy",
    "Dublin": "Ireland", "Cork": "Ireland", "Limerick": "Ireland",
    "Galway": "Ireland", "Waterford": "Ireland"
}

# %%
addresses = {}

# Ciudades en España
spain_cities = [
    "Jerez de la Frontera", "Madrid", "Barcelona", "Seville", "Valencia", "Bilbao",
    "Malaga", "Zaragoza", "Murcia", "Palma"
]

# Ciudades en Francia
france_cities = [
    "Paris", "Marseille", "Lyon", "Toulouse", "Nice", "Nantes",
    "Strasbourg", "Montpellier", "Bordeaux", "Lille"
]

# Ciudades en Reino Unido
uk_cities = [
    "London", "Manchester", "Liverpool", "Edinburgh", "Glasgow", "Birmingham",
    "Leeds", "Bristol", "Sheffield", "Leicester"
]

# Ciudades en Alemania
germany_cities = [
    "Berlin", "Munich", "Frankfurt", "Hamburg", "Cologne", "Stuttgart",
    "Düsseldorf", "Dortmund", "Essen", "Leipzig"
]

# Ciudades en Italia
italy_cities = [
    "Rome", "Milan", "Naples", "Turin", "Palermo", "Genoa",
    "Bologna", "Florence", "Bari", "Catania"
]

# Ciudades en Irlanda
ireland_cities = [
    "Dublin", "Cork", "Limerick", "Galway", "Waterford"
]

# Calles famosas por ciudad
streets_by_city = {
    "Jerez de la Frontera": ["Calle Larga", "Avenida Alcalde Álvaro Domecq", "Calle Sevilla"],
    "Madrid": ["Gran Vía", "Calle Mayor", "Paseo de la Castellana"],
    "Barcelona": ["La Rambla", "Passeig de Gràcia", "Avinguda Diagonal"],
    "Seville": ["Calle Sierpes", "Avenida de la Constitución", "Paseo de Colón"],
    "Valencia": ["Carrer de Colón", "Carrer de Xàtiva", "Carrer de la Pau"],
    "Bilbao": ["Gran Vía", "Calle Licenciado Poza", "Calle Ercilla"],
    "Malaga": ["Calle Marqués de Larios", "Calle Granada", "Calle Alcazabilla"],
    "Zaragoza": ["Paseo de la Independencia", "Calle Don Jaime I", "Calle Alfonso I"],
    "Murcia": ["Gran Vía Escultor Francisco Salzillo", "Avenida Teniente Flomesta", "Calle Trapería"],
    "Palma": ["Passeig des Born", "Carrer de Sant Miquel", "Plaça Major"],
    "Paris": ["Champs-Élysées", "Avenue de l'Opéra", "Rue de Rivoli"],
    "Marseille": ["Rue de la République", "Canebière", "Rue Saint-Ferréol"],
    "Lyon": ["Rue de la République", "Place Bellecour", "Rue Victor Hugo"],
    "Toulouse": ["Place du Capitole", "Allées Jean-Jaurès", "Rue de Metz"],
    "Nice": ["Promenade des Anglais", "Avenue Jean Médecin", "Place Masséna"],
    "Nantes": ["Rue du Calvaire", "Place Royale", "Rue Crébillon"],
    "Strasbourg": ["Place Kléber", "Rue du 22 Novembre", "Rue des Grandes Arcades"],
    "Montpellier": ["Place de la Comédie", "Rue de la Loge", "Rue Saint-Guilhem"],
    "Bordeaux": ["Rue Sainte-Catherine", "Place de la Bourse", "Quai des Chartrons"],
    "Lille": ["Grand'Place", "Rue de la Monnaie", "Rue Esquermoise"],
    "London": ["Oxford Street", "Regent Street", "Baker Street"],
    "Manchester": ["Deansgate", "Market Street", "King Street"],
    "Liverpool": ["Mathew Street", "Bold Street", "Castle Street"],
    "Edinburgh": ["Royal Mile", "Princes Street", "George Street"],
    "Glasgow": ["Buchanan Street", "Argyle Street", "Sauchiehall Street"],
    "Birmingham": ["Bullring", "New Street", "Broad Street"],
    "Leeds": ["Briggate", "Albion Street", "Boar Lane"],
    "Bristol": ["Park Street", "Baldwin Street", "Queen Square"],
    "Sheffield": ["Fargate", "Division Street", "Ecclesall Road"],
    "Leicester": ["High Street", "Granby Street", "Belvoir Street"],
    "Berlin": ["Unter den Linden", "Kurfürstendamm", "Friedrichstraße"],
    "Munich": ["Marienplatz", "Kaufingerstraße", "Maximilianstraße"],
    "Frankfurt": ["Zeil", "Schillerstraße", "Kaiserstraße"],
    "Hamburg": ["Mönckebergstraße", "Jungfernstieg", "Reeperbahn"],
    "Cologne": ["Schildergasse", "Hohe Straße", "Ehrenstraße"],
    "Stuttgart": ["Königstraße", "Calwer Straße", "Wilhelmsplatz"],
    "Düsseldorf": ["Königsallee", "Schadowstraße", "Flinger Straße"],
    "Dortmund": ["Westenhellweg", "Kleppingstraße", "Ostenhellweg"],
    "Essen": ["Kettwiger Straße", "Limbecker Platz", "Rüttenscheider Straße"],
    "Leipzig": ["Grimmaische Straße", "Nikolaistraße", "Karl-Liebknecht-Straße"],
    "Rome": ["Via del Corso", "Via Condotti", "Via Veneto"],
    "Milan": ["Corso Vittorio Emanuele II", "Via Montenapoleone", "Corso Buenos Aires"],
    "Naples": ["Spaccanapoli", "Via Toledo", "Via dei Tribunali"],
    "Turin": ["Via Roma", "Corso San Maurizio", "Via Po"],
    "Palermo": ["Via Vittorio Emanuele", "Corso Vittorio Emanuele", "Via Maqueda"],
    "Genoa": ["Via XX Settembre", "Via Garibaldi", "Via San Lorenzo"],
    "Bologna": ["Via dell'Indipendenza", "Via Ugo Bassi", "Via Rizzoli"],
    "Florence": ["Via de' Tornabuoni", "Piazza della Repubblica", "Via della Vigna Nuova"],
    "Bari": ["Via Sparano", "Corso Cavour", "Corso Vittorio Emanuele II"],
    "Catania": ["Via Etnea", "Via Crociferi", "Via Garibaldi"],
    "Dublin": ["Grafton Street", "O'Connell Street", "Henry Street"],
    "Cork": ["Patrick Street", "Oliver Plunkett Street", "Grand Parade"],
    "Limerick": ["O'Connell Street", "William Street", "Henry Street"],
    "Galway": ["Shop Street", "Eyre Square", "Dominick Street Lower"],
    "Waterford": ["The Quay", "Barronstrand Street", "O'Connell Street"]
}

# Generar direcciones para las ciudades
for city, streets in streets_by_city.items():
    for street in streets:
        for number in range(1, 101):
            address = f"{street}, {number}"
            addresses[address] = city

# %%
addresses
# Out:
# {'Calle Larga, 1': 'Jerez de la Frontera',
#  'Calle Larga, 2': 'Jerez de la Frontera',
#  'Calle Larga, 3': 'Jerez de la Frontera',
#  'Calle Larga, 4': 'Jerez de la Frontera',
#  'Calle Larga, 5': 'Jerez de la Frontera',
#  'Calle Larga, 6': 'Jerez de la Frontera',
#  'Calle Larga, 7': 'Jerez de la Frontera',
#  'Calle Larga, 8': 'Jerez de la Frontera',
#  'Calle Larga, 9': 'Jerez de la Frontera',
#  'Calle Larga, 10': 'Jerez de la Frontera',
#  'Calle Larga, 11': 'Jerez de la Frontera',
#  'Calle Larga, 12': 'Jerez de la Frontera',
#  'Calle Larga, 13': 'Jerez de la Frontera',
#  'Calle Larga, 14': 'Jerez de la Frontera',
#  'Calle Larga, 15': 'Jerez de la Frontera',
#  'Calle Larga, 16': 'Jerez de la Frontera',
#  'Calle Larga, 17': 'Jerez de la Frontera',
#  'Calle Larga, 18': 'Jerez de la Frontera',
#  'Calle Larga, 19': 'Jerez de la Frontera',
#  'Calle Larga, 20': 'Jerez de la Frontera',
#  'Calle Larga, 21': 'Jerez de la Frontera',
#  'Calle Larga, 22': 'Jerez de la Frontera',
#  'Calle Larga, 23': 'Jerez de la Frontera',
#  'Calle Larga, 24': 'Jerez de la Frontera',
#  'Calle Larga, 25': 'Jerez de la Frontera',
#  'Calle Larga, 26': 'Jerez de la Frontera',
#  'Calle Larga, 27': 'Jerez de la Frontera',
#  'Calle Larga, 28': 'Jerez de la Frontera',
#  'Calle Larga, 29': 'Jerez de la Frontera',
#  'Calle Larga, 30': 'Jerez de la Frontera',
#  'Calle Larga, 31': 'Jerez de la Frontera',
#  'Calle Larga, 32': 'Jerez de la Frontera',
#  'Calle Larga, 33': 'Jerez de la Frontera',
#  'Calle Larga, 34': 'Jerez de la Frontera',
#  'Calle Larga, 35': 'Jerez de la Frontera',
#  'Calle Larga, 36': 'Jerez de la Frontera',
#  'Calle Larga, 37': 'Jerez de la Frontera',
#  'Calle Larga, 38': 'Jerez de la Frontera',
#  'Calle Larga, 39': 'Jerez de la Frontera',
#  'Calle Larga, 40': 'Jerez de la Frontera',
#  'Calle Larga, 41': 'Jerez de la Frontera',
#  'Calle Larga, 42': 'Jerez de la Frontera',
#  'Calle Larga, 43': 'Jerez de la Frontera',
#  'Calle Larga, 44': 'Jerez de la Frontera',
#  'Calle Larga, 45': 'Jerez de la Frontera',
#  'Calle Larga, 46': 'Jerez de la Frontera',
#  'Calle Larga, 47': 'Jerez de la Frontera',
#  'Calle Larga, 48': 'Jerez de la Frontera',
#  'Calle Larga, 49': 'Jerez de la Frontera',
#  'Calle Larga, 50': 'Jerez de la Frontera',
#  'Calle Larga, 51': 'Jerez de la Frontera',
#  'Calle Larga, 52': 'Jerez de la Frontera',
#  'Calle Larga, 53': 'Jerez de la Frontera',
#  'Calle Larga, 54': 'Jerez de la Frontera',
#  'Calle Larga, 55': 'Jerez de la Frontera',
#  'Calle Larga, 56': 'Jerez de la Frontera',
#  'Calle Larga, 57': 'Jerez de la Frontera',
#  'Calle Larga, 58': 'Jerez de la Frontera',
#  'Calle Larga, 59': 'Jerez de la Frontera',
#  'Calle Larga, 60': 'Jerez de la Frontera',
#  'Calle Larga, 61': 'Jerez de la Frontera',
#  'Calle Larga, 62': 'Jerez de la Frontera',
#  'Calle Larga, 63': 'Jerez de la Frontera',
#  'Calle Larga, 64': 'Jerez de la Frontera',
#  'Calle Larga, 65': 'Jerez de la Frontera',
#  'Calle Larga, 66': 'Jerez de la Frontera',
#  'Calle Larga, 67': 'Jerez de la Frontera',
#  'Calle Larga, 68': 'Jerez de la Frontera',
#  'Calle Larga, 69': 'Jerez de la Frontera',
#  'Calle Larga, 70': 'Jerez de la Frontera',
#  'Calle Larga, 71': 'Jerez de la Frontera',
#  'Calle Larga, 72': 'Jerez de la Frontera',
#  'Calle Larga, 73': 'Jerez de la Frontera',
#  'Calle Larga, 74': 'Jerez de la Frontera',
#  'Calle Larga, 75': 'Jerez de la Frontera',
#  'Calle Larga, 76': 'Jerez de la Frontera',
#  'Calle Larga, 77': 'Jerez de la Frontera',
#  'Calle Larga, 78': 'Jerez de la Frontera',
#  'Calle Larga, 79': 'Jerez de la Frontera',
#  'Calle Larga, 80': 'Jerez de la Frontera',
#  'Calle Larga, 81': 'Jerez de la Frontera',
#  'Calle Larga, 82': 'Jerez de la Frontera',
#  'Calle Larga, 83': 'Jerez de la Frontera',
#  'Calle Larga, 84': 'Jerez de la Frontera',
#  'Calle Larga, 85': 'Jerez de la Frontera',
#  'Calle Larga, 86': 'Jerez de la Frontera',
#  'Calle Larga, 87': 'Jerez de la Frontera',
#  'Calle Larga, 88': 'Jerez de la Frontera',
#  'Calle Larga, 89': 'Jerez de la Frontera',
#  'Calle Larga, 90': 'Jerez de la Frontera',
#  'Calle Larga, 91': 'Jerez de la Frontera',
#  'Calle Larga, 92': 'Jerez de la Frontera',
#  'Calle Larga, 93': 'Jerez de la Frontera',
#  'Calle Larga, 94': 'Jerez de la Frontera',
#  'Calle Larga, 95': 'Jerez de la Frontera',
#  'Calle Larga, 96': 'Jerez de la Frontera',
#  'Calle Larga, 97': 'Jerez de la Frontera',
#  'Calle Larga, 98': 'Jerez de la Frontera',
#  'Calle Larga, 99': 'Jerez de la Frontera',
#  'Calle Larga, 100': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 1': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 2': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 3': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 4': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 5': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 6': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 7': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 8': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 9': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 10': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 11': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 12': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 13': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 14': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 15': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 16': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 17': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 18': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 19': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 20': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 21': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 22': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 23': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 24': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 25': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 26': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 27': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 28': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 29': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 30': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 31': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 32': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 33': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 34': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 35': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 36': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 37': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 38': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 39': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 40': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 41': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 42': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 43': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 44': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 45': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 46': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 47': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 48': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 49': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 50': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 51': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 52': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 53': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 54': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 55': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 56': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 57': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 58': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 59': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 60': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 61': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 62': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 63': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 64': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 65': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 66': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 67': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 68': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 69': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 70': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 71': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 72': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 73': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 74': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 75': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 76': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 77': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 78': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 79': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 80': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 81': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 82': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 83': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 84': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 85': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 86': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 87': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 88': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 89': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 90': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 91': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 92': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 93': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 94': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 95': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 96': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 97': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 98': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 99': 'Jerez de la Frontera',
#  'Avenida Alcalde Álvaro Domecq, 100': 'Jerez de la Frontera',
#  'Calle Sevilla, 1': 'Jerez de la Frontera',
#  'Calle Sevilla, 2': 'Jerez de la Frontera',
#  'Calle Sevilla, 3': 'Jerez de la Frontera',
#  'Calle Sevilla, 4': 'Jerez de la Frontera',
#  'Calle Sevilla, 5': 'Jerez de la Frontera',
#  'Calle Sevilla, 6': 'Jerez de la Frontera',
#  'Calle Sevilla, 7': 'Jerez de la Frontera',
#  'Calle Sevilla, 8': 'Jerez de la Frontera',
#  'Calle Sevilla, 9': 'Jerez de la Frontera',
#  'Calle Sevilla, 10': 'Jerez de la Frontera',
#  'Calle Sevilla, 11': 'Jerez de la Frontera',
#  'Calle Sevilla, 12': 'Jerez de la Frontera',
#  'Calle Sevilla, 13': 'Jerez de la Frontera',
#  'Calle Sevilla, 14': 'Jerez de la Frontera',
#  'Calle Sevilla, 15': 'Jerez de la Frontera',
#  'Calle Sevilla, 16': 'Jerez de la Frontera',
#  'Calle Sevilla, 17': 'Jerez de la Frontera',
#  'Calle Sevilla, 18': 'Jerez de la Frontera',
#  'Calle Sevilla, 19': 'Jerez de la Frontera',
#  'Calle Sevilla, 20': 'Jerez de la Frontera',
#  'Calle Sevilla, 21': 'Jerez de la Frontera',
#  'Calle Sevilla, 22': 'Jerez de la Frontera',
#  'Calle Sevilla, 23': 'Jerez de la Frontera',
#  'Calle Sevilla, 24': 'Jerez de la Frontera',
#  'Calle Sevilla, 25': 'Jerez de la Frontera',
#  'Calle Sevilla, 26': 'Jerez de la Frontera',
#  'Calle Sevilla, 27': 'Jerez de la Frontera',
#  'Calle Sevilla, 28': 'Jerez de la Frontera',
#  'Calle Sevilla, 29': 'Jerez de la Frontera',
#  'Calle Sevilla, 30': 'Jerez de la Frontera',
#  'Calle Sevilla, 31': 'Jerez de la Frontera',
#  'Calle Sevilla, 32': 'Jerez de la Frontera',
#  'Calle Sevilla, 33': 'Jerez de la Frontera',
#  'Calle Sevilla, 34': 'Jerez de la Frontera',
#  'Calle Sevilla, 35': 'Jerez de la Frontera',
#  'Calle Sevilla, 36': 'Jerez de la Frontera',
#  'Calle Sevilla, 37': 'Jerez de la Frontera',
#  'Calle Sevilla, 38': 'Jerez de la Frontera',
#  'Calle Sevilla, 39': 'Jerez de la Frontera',
#  'Calle Sevilla, 40': 'Jerez de la Frontera',
#  'Calle Sevilla, 41': 'Jerez de la Frontera',
#  'Calle Sevilla, 42': 'Jerez de la Frontera',
#  'Calle Sevilla, 43': 'Jerez de la Frontera',
#  'Calle Sevilla, 44': 'Jerez de la Frontera',
#  'Calle Sevilla, 45': 'Jerez de la Frontera',
#  'Calle Sevilla, 46': 'Jerez de la Frontera',
#  'Calle Sevilla, 47': 'Jerez de la Frontera',
#  'Calle Sevilla, 48': 'Jerez de la Frontera',
#  'Calle Sevilla, 49': 'Jerez de la Frontera',
#  'Calle Sevilla, 50': 'Jerez de la Frontera',
#  'Calle Sevilla, 51': 'Jerez de la Frontera',
#  'Calle Sevilla, 52': 'Jerez de la Frontera',
#  'Calle Sevilla, 53': 'Jerez de la Frontera',
#  'Calle Sevilla, 54': 'Jerez de la Frontera',
#  'Calle Sevilla, 55': 'Jerez de la Frontera',
#  'Calle Sevilla, 56': 'Jerez de la Frontera',
#  'Calle Sevilla, 57': 'Jerez de la Frontera',
#  'Calle Sevilla, 58': 'Jerez de la Frontera',
#  'Calle Sevilla, 59': 'Jerez de la Frontera',
#  'Calle Sevilla, 60': 'Jerez de la Frontera',
#  'Calle Sevilla, 61': 'Jerez de la Frontera',
#  'Calle Sevilla, 62': 'Jerez de la Frontera',
#  'Calle Sevilla, 63': 'Jerez de la Frontera',
#  'Calle Sevilla, 64': 'Jerez de la Frontera',
#  'Calle Sevilla, 65': 'Jerez de la Frontera',
#  'Calle Sevilla, 66': 'Jerez de la Frontera',
#  'Calle Sevilla, 67': 'Jerez de la Frontera',
#  'Calle Sevilla, 68': 'Jerez de la Frontera',
#  'Calle Sevilla, 69': 'Jerez de la Frontera',
#  'Calle Sevilla, 70': 'Jerez de la Frontera',
#  'Calle Sevilla, 71': 'Jerez de la Frontera',
#  'Calle Sevilla, 72': 'Jerez de la Frontera',
#  'Calle Sevilla, 73': 'Jerez de la Frontera',
#  'Calle Sevilla, 74': 'Jerez de la Frontera',
#  'Calle Sevilla, 75': 'Jerez de la Frontera',
#  'Calle Sevilla, 76': 'Jerez de la Frontera',
#  'Calle Sevilla, 77': 'Jerez de la Frontera',
#  'Calle Sevilla, 78': 'Jerez de la Frontera',
#  'Calle Sevilla, 79': 'Jerez de la Frontera',
#  'Calle Sevilla, 80': 'Jerez de la Frontera',
#  'Calle Sevilla, 81': 'Jerez de la Frontera',
#  'Calle Sevilla, 82': 'Jerez de la Frontera',
#  'Calle Sevilla, 83': 'Jerez de la Frontera',
#  'Calle Sevilla, 84': 'Jerez de la Frontera',
#  'Calle Sevilla, 85': 'Jerez de la Frontera',
#  'Calle Sevilla, 86': 'Jerez de la Frontera',
#  'Calle Sevilla, 87': 'Jerez de la Frontera',
#  'Calle Sevilla, 88': 'Jerez de la Frontera',
#  'Calle Sevilla, 89': 'Jerez de la Frontera',
#  'Calle Sevilla, 90': 'Jerez de la Frontera',
#  'Calle Sevilla, 91': 'Jerez de la Frontera',
#  'Calle Sevilla, 92': 'Jerez de la Frontera',
#  'Calle Sevilla, 93': 'Jerez de la Frontera',
#  'Calle Sevilla, 94': 'Jerez de la Frontera',
#  'Calle Sevilla, 95': 'Jerez de la Frontera',
#  'Calle Sevilla, 96': 'Jerez de la Frontera',
#  'Calle Sevilla, 97': 'Jerez de la Frontera',
#  'Calle Sevilla, 98': 'Jerez de la Frontera',
#  'Calle Sevilla, 99': 'Jerez de la Frontera',
#  'Calle Sevilla, 100': 'Jerez de la Frontera',
#  'Gran Vía, 1': 'Bilbao',
#  'Gran Vía, 2': 'Bilbao',
#  'Gran Vía, 3': 'Bilbao',
#  'Gran Vía, 4': 'Bilbao',
#  'Gran Vía, 5': 'Bilbao',
#  'Gran Vía, 6': 'Bilbao',
#  'Gran Vía, 7': 'Bilbao',
#  'Gran Vía, 8': 'Bilbao',
#  'Gran Vía, 9': 'Bilbao',
#  'Gran Vía, 10': 'Bilbao',
#  'Gran Vía, 11': 'Bilbao',
#  'Gran Vía, 12': 'Bilbao',
#  'Gran Vía, 13': 'Bilbao',
#  'Gran Vía, 14': 'Bilbao',
#  'Gran Vía, 15': 'Bilbao',
#  'Gran Vía, 16': 'Bilbao',
#  'Gran Vía, 17': 'Bilbao',
#  'Gran Vía, 18': 'Bilbao',
#  'Gran Vía, 19': 'Bilbao',
#  'Gran Vía, 20': 'Bilbao',
#  'Gran Vía, 21': 'Bilbao',
#  'Gran Vía, 22': 'Bilbao',
#  'Gran Vía, 23': 'Bilbao',
#  'Gran Vía, 24': 'Bilbao',
#  'Gran Vía, 25': 'Bilbao',
#  'Gran Vía, 26': 'Bilbao',
#  'Gran Vía, 27': 'Bilbao',
#  'Gran Vía, 28': 'Bilbao',
#  'Gran Vía, 29': 'Bilbao',
#  'Gran Vía, 30': 'Bilbao',
#  'Gran Vía, 31': 'Bilbao',
#  'Gran Vía, 32': 'Bilbao',
#  'Gran Vía, 33': 'Bilbao',
#  'Gran Vía, 34': 'Bilbao',
#  'Gran Vía, 35': 'Bilbao',
#  'Gran Vía, 36': 'Bilbao',
#  'Gran Vía, 37': 'Bilbao',
#  'Gran Vía, 38': 'Bilbao',
#  'Gran Vía, 39': 'Bilbao',
#  'Gran Vía, 40': 'Bilbao',
#  'Gran Vía, 41': 'Bilbao',
#  'Gran Vía, 42': 'Bilbao',
#  'Gran Vía, 43': 'Bilbao',
#  'Gran Vía, 44': 'Bilbao',
#  'Gran Vía, 45': 'Bilbao',
#  'Gran Vía, 46': 'Bilbao',
#  'Gran Vía, 47': 'Bilbao',
#  'Gran Vía, 48': 'Bilbao',
#  'Gran Vía, 49': 'Bilbao',
#  'Gran Vía, 50': 'Bilbao',
#  'Gran Vía, 51': 'Bilbao',
#  'Gran Vía, 52': 'Bilbao',
#  'Gran Vía, 53': 'Bilbao',
#  'Gran Vía, 54': 'Bilbao',
#  'Gran Vía, 55': 'Bilbao',
#  'Gran Vía, 56': 'Bilbao',
#  'Gran Vía, 57': 'Bilbao',
#  'Gran Vía, 58': 'Bilbao',
#  'Gran Vía, 59': 'Bilbao',
#  'Gran Vía, 60': 'Bilbao',
#  'Gran Vía, 61': 'Bilbao',
#  'Gran Vía, 62': 'Bilbao',
#  'Gran Vía, 63': 'Bilbao',
#  'Gran Vía, 64': 'Bilbao',
#  'Gran Vía, 65': 'Bilbao',
#  'Gran Vía, 66': 'Bilbao',
#  'Gran Vía, 67': 'Bilbao',
#  'Gran Vía, 68': 'Bilbao',
#  'Gran Vía, 69': 'Bilbao',
#  'Gran Vía, 70': 'Bilbao',
#  'Gran Vía, 71': 'Bilbao',
#  'Gran Vía, 72': 'Bilbao',
#  'Gran Vía, 73': 'Bilbao',
#  'Gran Vía, 74': 'Bilbao',
#  'Gran Vía, 75': 'Bilbao',
#  'Gran Vía, 76': 'Bilbao',
#  'Gran Vía, 77': 'Bilbao',
#  'Gran Vía, 78': 'Bilbao',
#  'Gran Vía, 79': 'Bilbao',
#  'Gran Vía, 80': 'Bilbao',
#  'Gran Vía, 81': 'Bilbao',
#  'Gran Vía, 82': 'Bilbao',
#  'Gran Vía, 83': 'Bilbao',
#  'Gran Vía, 84': 'Bilbao',
#  'Gran Vía, 85': 'Bilbao',
#  'Gran Vía, 86': 'Bilbao',
#  'Gran Vía, 87': 'Bilbao',
#  'Gran Vía, 88': 'Bilbao',
#  'Gran Vía, 89': 'Bilbao',
#  'Gran Vía, 90': 'Bilbao',
#  'Gran Vía, 91': 'Bilbao',
#  'Gran Vía, 92': 'Bilbao',
#  'Gran Vía, 93': 'Bilbao',
#  'Gran Vía, 94': 'Bilbao',
#  'Gran Vía, 95': 'Bilbao',
#  'Gran Vía, 96': 'Bilbao',
#  'Gran Vía, 97': 'Bilbao',
#  'Gran Vía, 98': 'Bilbao',
#  'Gran Vía, 99': 'Bilbao',
#  'Gran Vía, 100': 'Bilbao',
#  'Calle Mayor, 1': 'Madrid',
#  'Calle Mayor, 2': 'Madrid',
#  'Calle Mayor, 3': 'Madrid',
#  'Calle Mayor, 4': 'Madrid',
#  'Calle Mayor, 5': 'Madrid',
#  'Calle Mayor, 6': 'Madrid',
#  'Calle Mayor, 7': 'Madrid',
#  'Calle Mayor, 8': 'Madrid',
#  'Calle Mayor, 9': 'Madrid',
#  'Calle Mayor, 10': 'Madrid',
#  'Calle Mayor, 11': 'Madrid',
#  'Calle Mayor, 12': 'Madrid',
#  'Calle Mayor, 13': 'Madrid',
#  'Calle Mayor, 14': 'Madrid',
#  'Calle Mayor, 15': 'Madrid',
#  'Calle Mayor, 16': 'Madrid',
#  'Calle Mayor, 17': 'Madrid',
#  'Calle Mayor, 18': 'Madrid',
#  'Calle Mayor, 19': 'Madrid',
#  'Calle Mayor, 20': 'Madrid',
#  'Calle Mayor, 21': 'Madrid',
#  'Calle Mayor, 22': 'Madrid',
#  'Calle Mayor, 23': 'Madrid',
#  'Calle Mayor, 24': 'Madrid',
#  'Calle Mayor, 25': 'Madrid',
#  'Calle Mayor, 26': 'Madrid',
#  'Calle Mayor, 27': 'Madrid',
#  'Calle Mayor, 28': 'Madrid',
#  'Calle Mayor, 29': 'Madrid',
#  'Calle Mayor, 30': 'Madrid',
#  'Calle Mayor, 31': 'Madrid',
#  'Calle Mayor, 32': 'Madrid',
#  'Calle Mayor, 33': 'Madrid',
#  'Calle Mayor, 34': 'Madrid',
#  'Calle Mayor, 35': 'Madrid',
#  'Calle Mayor, 36': 'Madrid',
#  'Calle Mayor, 37': 'Madrid',
#  'Calle Mayor, 38': 'Madrid',
#  'Calle Mayor, 39': 'Madrid',
#  'Calle Mayor, 40': 'Madrid',
#  'Calle Mayor, 41': 'Madrid',
#  'Calle Mayor, 42': 'Madrid',
#  'Calle Mayor, 43': 'Madrid',
#  'Calle Mayor, 44': 'Madrid',
#  'Calle Mayor, 45': 'Madrid',
#  'Calle Mayor, 46': 'Madrid',
#  'Calle Mayor, 47': 'Madrid',
#  'Calle Mayor, 48': 'Madrid',
#  'Calle Mayor, 49': 'Madrid',
#  'Calle Mayor, 50': 'Madrid',
#  'Calle Mayor, 51': 'Madrid',
#  'Calle Mayor, 52': 'Madrid',
#  'Calle Mayor, 53': 'Madrid',
#  'Calle Mayor, 54': 'Madrid',
#  'Calle Mayor, 55': 'Madrid',
#  'Calle Mayor, 56': 'Madrid',
#  'Calle Mayor, 57': 'Madrid',
#  'Calle Mayor, 58': 'Madrid',
#  'Calle Mayor, 59': 'Madrid',
#  'Calle Mayor, 60': 'Madrid',
#  'Calle Mayor, 61': 'Madrid',
#  'Calle Mayor, 62': 'Madrid',
#  'Calle Mayor, 63': 'Madrid',
#  'Calle Mayor, 64': 'Madrid',
#  'Calle Mayor, 65': 'Madrid',
#  'Calle Mayor, 66': 'Madrid',
#  'Calle Mayor, 67': 'Madrid',
#  'Calle Mayor, 68': 'Madrid',
#  'Calle Mayor, 69': 'Madrid',
#  'Calle Mayor, 70': 'Madrid',
#  'Calle Mayor, 71': 'Madrid',
#  'Calle Mayor, 72': 'Madrid',
#  'Calle Mayor, 73': 'Madrid',
#  'Calle Mayor, 74': 'Madrid',
#  'Calle Mayor, 75': 'Madrid',
#  'Calle Mayor, 76': 'Madrid',
#  'Calle Mayor, 77': 'Madrid',
#  'Calle Mayor, 78': 'Madrid',
#  'Calle Mayor, 79': 'Madrid',
#  'Calle Mayor, 80': 'Madrid',
#  'Calle Mayor, 81': 'Madrid',
#  'Calle Mayor, 82': 'Madrid',
#  'Calle Mayor, 83': 'Madrid',
#  'Calle Mayor, 84': 'Madrid',
#  'Calle Mayor, 85': 'Madrid',
#  'Calle Mayor, 86': 'Madrid',
#  'Calle Mayor, 87': 'Madrid',
#  'Calle Mayor, 88': 'Madrid',
#  'Calle Mayor, 89': 'Madrid',
#  'Calle Mayor, 90': 'Madrid',
#  'Calle Mayor, 91': 'Madrid',
#  'Calle Mayor, 92': 'Madrid',
#  'Calle Mayor, 93': 'Madrid',
#  'Calle Mayor, 94': 'Madrid',
#  'Calle Mayor, 95': 'Madrid',
#  'Calle Mayor, 96': 'Madrid',
#  'Calle Mayor, 97': 'Madrid',
#  'Calle Mayor, 98': 'Madrid',
#  'Calle Mayor, 99': 'Madrid',
#  'Calle Mayor, 100': 'Madrid',
#  'Paseo de la Castellana, 1': 'Madrid',
#  'Paseo de la Castellana, 2': 'Madrid',
#  'Paseo de la Castellana, 3': 'Madrid',
#  'Paseo de la Castellana, 4': 'Madrid',
#  'Paseo de la Castellana, 5': 'Madrid',
#  'Paseo de la Castellana, 6': 'Madrid',
#  'Paseo de la Castellana, 7': 'Madrid',
#  'Paseo de la Castellana, 8': 'Madrid',
#  'Paseo de la Castellana, 9': 'Madrid',
#  'Paseo de la Castellana, 10': 'Madrid',
#  'Paseo de la Castellana, 11': 'Madrid',
#  'Paseo de la Castellana, 12': 'Madrid',
#  'Paseo de la Castellana, 13': 'Madrid',
#  'Paseo de la Castellana, 14': 'Madrid',
#  'Paseo de la Castellana, 15': 'Madrid',
#  'Paseo de la Castellana, 16': 'Madrid',
#  'Paseo de la Castellana, 17': 'Madrid',
#  'Paseo de la Castellana, 18': 'Madrid',
#  'Paseo de la Castellana, 19': 'Madrid',
#  'Paseo de la Castellana, 20': 'Madrid',
#  'Paseo de la Castellana, 21': 'Madrid',
#  'Paseo de la Castellana, 22': 'Madrid',
#  'Paseo de la Castellana, 23': 'Madrid',
#  'Paseo de la Castellana, 24': 'Madrid',
#  'Paseo de la Castellana, 25': 'Madrid',
#  'Paseo de la Castellana, 26': 'Madrid',
#  'Paseo de la Castellana, 27': 'Madrid',
#  'Paseo de la Castellana, 28': 'Madrid',
#  'Paseo de la Castellana, 29': 'Madrid',
#  'Paseo de la Castellana, 30': 'Madrid',
#  'Paseo de la Castellana, 31': 'Madrid',
#  'Paseo de la Castellana, 32': 'Madrid',
#  'Paseo de la Castellana, 33': 'Madrid',
#  'Paseo de la Castellana, 34': 'Madrid',
#  'Paseo de la Castellana, 35': 'Madrid',
#  'Paseo de la Castellana, 36': 'Madrid',
#  'Paseo de la Castellana, 37': 'Madrid',
#  'Paseo de la Castellana, 38': 'Madrid',
#  'Paseo de la Castellana, 39': 'Madrid',
#  'Paseo de la Castellana, 40': 'Madrid',
#  'Paseo de la Castellana, 41': 'Madrid',
#  'Paseo de la Castellana, 42': 'Madrid',
#  'Paseo de la Castellana, 43': 'Madrid',
#  'Paseo de la Castellana, 44': 'Madrid',
#  'Paseo de la Castellana, 45': 'Madrid',
#  'Paseo de la Castellana, 46': 'Madrid',
#  'Paseo de la Castellana, 47': 'Madrid',
#  'Paseo de la Castellana, 48': 'Madrid',
#  'Paseo de la Castellana, 49': 'Madrid',
#  'Paseo de la Castellana, 50': 'Madrid',
#  'Paseo de la Castellana, 51': 'Madrid',
#  'Paseo de la Castellana, 52': 'Madrid',
#  'Paseo de la Castellana, 53': 'Madrid',
#  'Paseo de la Castellana, 54': 'Madrid',
#  'Paseo de la Castellana, 55': 'Madrid',
#  'Paseo de la Castellana, 56': 'Madrid',
#  'Paseo de la Castellana, 57': 'Madrid',
#  'Paseo de la Castellana, 58': 'Madrid',
#  'Paseo de la Castellana, 59': 'Madrid',
#  'Paseo de la Castellana, 60': 'Madrid',
#  'Paseo de la Castellana, 61': 'Madrid',
#  'Paseo de la Castellana, 62': 'Madrid',
#  'Paseo de la Castellana, 63': 'Madrid',
#  'Paseo de la Castellana, 64': 'Madrid',
#  'Paseo de la Castellana, 65': 'Madrid',
#  'Paseo de la Castellana, 66': 'Madrid',
#  'Paseo de la Castellana, 67': 'Madrid',
#  'Paseo de la Castellana, 68': 'Madrid',
#  'Paseo de la Castellana, 69': 'Madrid',
#  'Paseo de la Castellana, 70': 'Madrid',
#  'Paseo de la Castellana, 71': 'Madrid',
#  'Paseo de la Castellana, 72': 'Madrid',
#  'Paseo de la Castellana, 73': 'Madrid',
#  'Paseo de la Castellana, 74': 'Madrid',
#  'Paseo de la Castellana, 75': 'Madrid',
#  'Paseo de la Castellana, 76': 'Madrid',
#  'Paseo de la Castellana, 77': 'Madrid',
#  'Paseo de la Castellana, 78': 'Madrid',
#  'Paseo de la Castellana, 79': 'Madrid',
#  'Paseo de la Castellana, 80': 'Madrid',
#  'Paseo de la Castellana, 81': 'Madrid',
#  'Paseo de la Castellana, 82': 'Madrid',
#  'Paseo de la Castellana, 83': 'Madrid',
#  'Paseo de la Castellana, 84': 'Madrid',
#  'Paseo de la Castellana, 85': 'Madrid',
#  'Paseo de la Castellana, 86': 'Madrid',
#  'Paseo de la Castellana, 87': 'Madrid',
#  'Paseo de la Castellana, 88': 'Madrid',
#  'Paseo de la Castellana, 89': 'Madrid',
#  'Paseo de la Castellana, 90': 'Madrid',
#  'Paseo de la Castellana, 91': 'Madrid',
#  'Paseo de la Castellana, 92': 'Madrid',
#  'Paseo de la Castellana, 93': 'Madrid',
#  'Paseo de la Castellana, 94': 'Madrid',
#  'Paseo de la Castellana, 95': 'Madrid',
#  'Paseo de la Castellana, 96': 'Madrid',
#  'Paseo de la Castellana, 97': 'Madrid',
#  'Paseo de la Castellana, 98': 'Madrid',
#  'Paseo de la Castellana, 99': 'Madrid',
#  'Paseo de la Castellana, 100': 'Madrid',
#  'La Rambla, 1': 'Barcelona',
#  'La Rambla, 2': 'Barcelona',
#  'La Rambla, 3': 'Barcelona',
#  'La Rambla, 4': 'Barcelona',
#  'La Rambla, 5': 'Barcelona',
#  'La Rambla, 6': 'Barcelona',
#  'La Rambla, 7': 'Barcelona',
#  'La Rambla, 8': 'Barcelona',
#  'La Rambla, 9': 'Barcelona',
#  'La Rambla, 10': 'Barcelona',
#  'La Rambla, 11': 'Barcelona',
#  'La Rambla, 12': 'Barcelona',
#  'La Rambla, 13': 'Barcelona',
#  'La Rambla, 14': 'Barcelona',
#  'La Rambla, 15': 'Barcelona',
#  'La Rambla, 16': 'Barcelona',
#  'La Rambla, 17': 'Barcelona',
#  'La Rambla, 18': 'Barcelona',
#  'La Rambla, 19': 'Barcelona',
#  'La Rambla, 20': 'Barcelona',
#  'La Rambla, 21': 'Barcelona',
#  'La Rambla, 22': 'Barcelona',
#  'La Rambla, 23': 'Barcelona',
#  'La Rambla, 24': 'Barcelona',
#  'La Rambla, 25': 'Barcelona',
#  'La Rambla, 26': 'Barcelona',
#  'La Rambla, 27': 'Barcelona',
#  'La Rambla, 28': 'Barcelona',
#  'La Rambla, 29': 'Barcelona',
#  'La Rambla, 30': 'Barcelona',
#  'La Rambla, 31': 'Barcelona',
#  'La Rambla, 32': 'Barcelona',
#  'La Rambla, 33': 'Barcelona',
#  'La Rambla, 34': 'Barcelona',
#  'La Rambla, 35': 'Barcelona',
#  'La Rambla, 36': 'Barcelona',
#  'La Rambla, 37': 'Barcelona',
#  'La Rambla, 38': 'Barcelona',
#  'La Rambla, 39': 'Barcelona',
#  'La Rambla, 40': 'Barcelona',
#  'La Rambla, 41': 'Barcelona',
#  'La Rambla, 42': 'Barcelona',
#  'La Rambla, 43': 'Barcelona',
#  'La Rambla, 44': 'Barcelona',
#  'La Rambla, 45': 'Barcelona',
#  'La Rambla, 46': 'Barcelona',
#  'La Rambla, 47': 'Barcelona',
#  'La Rambla, 48': 'Barcelona',
#  'La Rambla, 49': 'Barcelona',
#  'La Rambla, 50': 'Barcelona',
#  'La Rambla, 51': 'Barcelona',
#  'La Rambla, 52': 'Barcelona',
#  'La Rambla, 53': 'Barcelona',
#  'La Rambla, 54': 'Barcelona',
#  'La Rambla, 55': 'Barcelona',
#  'La Rambla, 56': 'Barcelona',
#  'La Rambla, 57': 'Barcelona',
#  'La Rambla, 58': 'Barcelona',
#  'La Rambla, 59': 'Barcelona',
#  'La Rambla, 60': 'Barcelona',
#  'La Rambla, 61': 'Barcelona',
#  'La Rambla, 62': 'Barcelona',
#  'La Rambla, 63': 'Barcelona',
#  'La Rambla, 64': 'Barcelona',
#  'La Rambla, 65': 'Barcelona',
#  'La Rambla, 66': 'Barcelona',
#  'La Rambla, 67': 'Barcelona',
#  'La Rambla, 68': 'Barcelona',
#  'La Rambla, 69': 'Barcelona',
#  'La Rambla, 70': 'Barcelona',
#  'La Rambla, 71': 'Barcelona',
#  'La Rambla, 72': 'Barcelona',
#  'La Rambla, 73': 'Barcelona',
#  'La Rambla, 74': 'Barcelona',
#  'La Rambla, 75': 'Barcelona',
#  'La Rambla, 76': 'Barcelona',
#  'La Rambla, 77': 'Barcelona',
#  'La Rambla, 78': 'Barcelona',
#  'La Rambla, 79': 'Barcelona',
#  'La Rambla, 80': 'Barcelona',
#  'La Rambla, 81': 'Barcelona',
#  'La Rambla, 82': 'Barcelona',
#  'La Rambla, 83': 'Barcelona',
#  'La Rambla, 84': 'Barcelona',
#  'La Rambla, 85': 'Barcelona',
#  'La Rambla, 86': 'Barcelona',
#  'La Rambla, 87': 'Barcelona',
#  'La Rambla, 88': 'Barcelona',
#  'La Rambla, 89': 'Barcelona',
#  'La Rambla, 90': 'Barcelona',
#  'La Rambla, 91': 'Barcelona',
#  'La Rambla, 92': 'Barcelona',
#  'La Rambla, 93': 'Barcelona',
#  'La Rambla, 94': 'Barcelona',
#  'La Rambla, 95': 'Barcelona',
#  'La Rambla, 96': 'Barcelona',
#  'La Rambla, 97': 'Barcelona',
#  'La Rambla, 98': 'Barcelona',
#  'La Rambla, 99': 'Barcelona',
#  'La Rambla, 100': 'Barcelona',
#  'Passeig de Gràcia, 1': 'Barcelona',
#  'Passeig de Gràcia, 2': 'Barcelona',
#  'Passeig de Gràcia, 3': 'Barcelona',
#  'Passeig de Gràcia, 4': 'Barcelona',
#  'Passeig de Gràcia, 5': 'Barcelona',
#  'Passeig de Gràcia, 6': 'Barcelona',
#  'Passeig de Gràcia, 7': 'Barcelona',
#  'Passeig de Gràcia, 8': 'Barcelona',
#  'Passeig de Gràcia, 9': 'Barcelona',
#  'Passeig de Gràcia, 10': 'Barcelona',
#  'Passeig de Gràcia, 11': 'Barcelona',
#  'Passeig de Gràcia, 12': 'Barcelona',
#  'Passeig de Gràcia, 13': 'Barcelona',
#  'Passeig de Gràcia, 14': 'Barcelona',
#  'Passeig de Gràcia, 15': 'Barcelona',
#  'Passeig de Gràcia, 16': 'Barcelona',
#  'Passeig de Gràcia, 17': 'Barcelona',
#  'Passeig de Gràcia, 18': 'Barcelona',
#  'Passeig de Gràcia, 19': 'Barcelona',
#  'Passeig de Gràcia, 20': 'Barcelona',
#  'Passeig de Gràcia, 21': 'Barcelona',
#  'Passeig de Gràcia, 22': 'Barcelona',
#  'Passeig de Gràcia, 23': 'Barcelona',
#  'Passeig de Gràcia, 24': 'Barcelona',
#  'Passeig de Gràcia, 25': 'Barcelona',
#  'Passeig de Gràcia, 26': 'Barcelona',
#  'Passeig de Gràcia, 27': 'Barcelona',
#  'Passeig de Gràcia, 28': 'Barcelona',
#  'Passeig de Gràcia, 29': 'Barcelona',
#  'Passeig de Gràcia, 30': 'Barcelona',
#  'Passeig de Gràcia, 31': 'Barcelona',
#  'Passeig de Gràcia, 32': 'Barcelona',
#  'Passeig de Gràcia, 33': 'Barcelona',
#  'Passeig de Gràcia, 34': 'Barcelona',
#  'Passeig de Gràcia, 35': 'Barcelona',
#  'Passeig de Gràcia, 36': 'Barcelona',
#  'Passeig de Gràcia, 37': 'Barcelona',
#  'Passeig de Gràcia, 38': 'Barcelona',
#  'Passeig de Gràcia, 39': 'Barcelona',
#  'Passeig de Gràcia, 40': 'Barcelona',
#  'Passeig de Gràcia, 41': 'Barcelona',
#  'Passeig de Gràcia, 42': 'Barcelona',
#  'Passeig de Gràcia, 43': 'Barcelona',
#  'Passeig de Gràcia, 44': 'Barcelona',
#  'Passeig de Gràcia, 45': 'Barcelona',
#  'Passeig de Gràcia, 46': 'Barcelona',
#  'Passeig de Gràcia, 47': 'Barcelona',
#  'Passeig de Gràcia, 48': 'Barcelona',
#  'Passeig de Gràcia, 49': 'Barcelona',
#  'Passeig de Gràcia, 50': 'Barcelona',
#  'Passeig de Gràcia, 51': 'Barcelona',
#  'Passeig de Gràcia, 52': 'Barcelona',
#  'Passeig de Gràcia, 53': 'Barcelona',
#  'Passeig de Gràcia, 54': 'Barcelona',
#  'Passeig de Gràcia, 55': 'Barcelona',
#  'Passeig de Gràcia, 56': 'Barcelona',
#  'Passeig de Gràcia, 57': 'Barcelona',
#  'Passeig de Gràcia, 58': 'Barcelona',
#  'Passeig de Gràcia, 59': 'Barcelona',
#  'Passeig de Gràcia, 60': 'Barcelona',
#  'Passeig de Gràcia, 61': 'Barcelona',
#  'Passeig de Gràcia, 62': 'Barcelona',
#  'Passeig de Gràcia, 63': 'Barcelona',
#  'Passeig de Gràcia, 64': 'Barcelona',
#  'Passeig de Gràcia, 65': 'Barcelona',
#  'Passeig de Gràcia, 66': 'Barcelona',
#  'Passeig de Gràcia, 67': 'Barcelona',
#  'Passeig de Gràcia, 68': 'Barcelona',
#  'Passeig de Gràcia, 69': 'Barcelona',
#  'Passeig de Gràcia, 70': 'Barcelona',
#  'Passeig de Gràcia, 71': 'Barcelona',
#  'Passeig de Gràcia, 72': 'Barcelona',
#  'Passeig de Gràcia, 73': 'Barcelona',
#  'Passeig de Gràcia, 74': 'Barcelona',
#  'Passeig de Gràcia, 75': 'Barcelona',
#  'Passeig de Gràcia, 76': 'Barcelona',
#  'Passeig de Gràcia, 77': 'Barcelona',
#  'Passeig de Gràcia, 78': 'Barcelona',
#  'Passeig de Gràcia, 79': 'Barcelona',
#  'Passeig de Gràcia, 80': 'Barcelona',
#  'Passeig de Gràcia, 81': 'Barcelona',
#  'Passeig de Gràcia, 82': 'Barcelona',
#  'Passeig de Gràcia, 83': 'Barcelona',
#  'Passeig de Gràcia, 84': 'Barcelona',
#  'Passeig de Gràcia, 85': 'Barcelona',
#  'Passeig de Gràcia, 86': 'Barcelona',
#  'Passeig de Gràcia, 87': 'Barcelona',
#  'Passeig de Gràcia, 88': 'Barcelona',
#  'Passeig de Gràcia, 89': 'Barcelona',
#  'Passeig de Gràcia, 90': 'Barcelona',
#  'Passeig de Gràcia, 91': 'Barcelona',
#  'Passeig de Gràcia, 92': 'Barcelona',
#  'Passeig de Gràcia, 93': 'Barcelona',
#  'Passeig de Gràcia, 94': 'Barcelona',
#  'Passeig de Gràcia, 95': 'Barcelona',
#  'Passeig de Gràcia, 96': 'Barcelona',
#  'Passeig de Gràcia, 97': 'Barcelona',
#  'Passeig de Gràcia, 98': 'Barcelona',
#  'Passeig de Gràcia, 99': 'Barcelona',
#  'Passeig de Gràcia, 100': 'Barcelona',
#  'Avinguda Diagonal, 1': 'Barcelona',
#  'Avinguda Diagonal, 2': 'Barcelona',
#  'Avinguda Diagonal, 3': 'Barcelona',
#  'Avinguda Diagonal, 4': 'Barcelona',
#  'Avinguda Diagonal, 5': 'Barcelona',
#  'Avinguda Diagonal, 6': 'Barcelona',
#  'Avinguda Diagonal, 7': 'Barcelona',
#  'Avinguda Diagonal, 8': 'Barcelona',
#  'Avinguda Diagonal, 9': 'Barcelona',
#  'Avinguda Diagonal, 10': 'Barcelona',
#  'Avinguda Diagonal, 11': 'Barcelona',
#  'Avinguda Diagonal, 12': 'Barcelona',
#  'Avinguda Diagonal, 13': 'Barcelona',
#  'Avinguda Diagonal, 14': 'Barcelona',
#  'Avinguda Diagonal, 15': 'Barcelona',
#  'Avinguda Diagonal, 16': 'Barcelona',
#  'Avinguda Diagonal, 17': 'Barcelona',
#  'Avinguda Diagonal, 18': 'Barcelona',
#  'Avinguda Diagonal, 19': 'Barcelona',
#  'Avinguda Diagonal, 20': 'Barcelona',
#  'Avinguda Diagonal, 21': 'Barcelona',
#  'Avinguda Diagonal, 22': 'Barcelona',
#  'Avinguda Diagonal, 23': 'Barcelona',
#  'Avinguda Diagonal, 24': 'Barcelona',
#  'Avinguda Diagonal, 25': 'Barcelona',
#  'Avinguda Diagonal, 26': 'Barcelona',
#  'Avinguda Diagonal, 27': 'Barcelona',
#  'Avinguda Diagonal, 28': 'Barcelona',
#  'Avinguda Diagonal, 29': 'Barcelona',
#  'Avinguda Diagonal, 30': 'Barcelona',
#  'Avinguda Diagonal, 31': 'Barcelona',
#  'Avinguda Diagonal, 32': 'Barcelona',
#  'Avinguda Diagonal, 33': 'Barcelona',
#  'Avinguda Diagonal, 34': 'Barcelona',
#  'Avinguda Diagonal, 35': 'Barcelona',
#  'Avinguda Diagonal, 36': 'Barcelona',
#  'Avinguda Diagonal, 37': 'Barcelona',
#  'Avinguda Diagonal, 38': 'Barcelona',
#  'Avinguda Diagonal, 39': 'Barcelona',
#  'Avinguda Diagonal, 40': 'Barcelona',
#  'Avinguda Diagonal, 41': 'Barcelona',
#  'Avinguda Diagonal, 42': 'Barcelona',
#  'Avinguda Diagonal, 43': 'Barcelona',
#  'Avinguda Diagonal, 44': 'Barcelona',
#  'Avinguda Diagonal, 45': 'Barcelona',
#  'Avinguda Diagonal, 46': 'Barcelona',
#  'Avinguda Diagonal, 47': 'Barcelona',
#  'Avinguda Diagonal, 48': 'Barcelona',
#  'Avinguda Diagonal, 49': 'Barcelona',
#  'Avinguda Diagonal, 50': 'Barcelona',
#  'Avinguda Diagonal, 51': 'Barcelona',
#  'Avinguda Diagonal, 52': 'Barcelona',
#  'Avinguda Diagonal, 53': 'Barcelona',
#  'Avinguda Diagonal, 54': 'Barcelona',
#  'Avinguda Diagonal, 55': 'Barcelona',
#  'Avinguda Diagonal, 56': 'Barcelona',
#  'Avinguda Diagonal, 57': 'Barcelona',
#  'Avinguda Diagonal, 58': 'Barcelona',
#  'Avinguda Diagonal, 59': 'Barcelona',
#  'Avinguda Diagonal, 60': 'Barcelona',
#  'Avinguda Diagonal, 61': 'Barcelona',
#  'Avinguda Diagonal, 62': 'Barcelona',
#  'Avinguda Diagonal, 63': 'Barcelona',
#  'Avinguda Diagonal, 64': 'Barcelona',
#  'Avinguda Diagonal, 65': 'Barcelona',
#  'Avinguda Diagonal, 66': 'Barcelona',
#  'Avinguda Diagonal, 67': 'Barcelona',
#  'Avinguda Diagonal, 68': 'Barcelona',
#  'Avinguda Diagonal, 69': 'Barcelona',
#  'Avinguda Diagonal, 70': 'Barcelona',
#  'Avinguda Diagonal, 71': 'Barcelona',
#  'Avinguda Diagonal, 72': 'Barcelona',
#  'Avinguda Diagonal, 73': 'Barcelona',
#  'Avinguda Diagonal, 74': 'Barcelona',
#  'Avinguda Diagonal, 75': 'Barcelona',
#  'Avinguda Diagonal, 76': 'Barcelona',
#  'Avinguda Diagonal, 77': 'Barcelona',
#  'Avinguda Diagonal, 78': 'Barcelona',
#  'Avinguda Diagonal, 79': 'Barcelona',
#  'Avinguda Diagonal, 80': 'Barcelona',
#  'Avinguda Diagonal, 81': 'Barcelona',
#  'Avinguda Diagonal, 82': 'Barcelona',
#  'Avinguda Diagonal, 83': 'Barcelona',
#  'Avinguda Diagonal, 84': 'Barcelona',
#  'Avinguda Diagonal, 85': 'Barcelona',
#  'Avinguda Diagonal, 86': 'Barcelona',
#  'Avinguda Diagonal, 87': 'Barcelona',
#  'Avinguda Diagonal, 88': 'Barcelona',
#  'Avinguda Diagonal, 89': 'Barcelona',
#  'Avinguda Diagonal, 90': 'Barcelona',
#  'Avinguda Diagonal, 91': 'Barcelona',
#  'Avinguda Diagonal, 92': 'Barcelona',
#  'Avinguda Diagonal, 93': 'Barcelona',
#  'Avinguda Diagonal, 94': 'Barcelona',
#  'Avinguda Diagonal, 95': 'Barcelona',
#  'Avinguda Diagonal, 96': 'Barcelona',
#  'Avinguda Diagonal, 97': 'Barcelona',
#  'Avinguda Diagonal, 98': 'Barcelona',
#  'Avinguda Diagonal, 99': 'Barcelona',
#  'Avinguda Diagonal, 100': 'Barcelona',
#  'Calle Sierpes, 1': 'Seville',
#  'Calle Sierpes, 2': 'Seville',
#  'Calle Sierpes, 3': 'Seville',
#  'Calle Sierpes, 4': 'Seville',
#  'Calle Sierpes, 5': 'Seville',
#  'Calle Sierpes, 6': 'Seville',
#  'Calle Sierpes, 7': 'Seville',
#  'Calle Sierpes, 8': 'Seville',
#  'Calle Sierpes, 9': 'Seville',
#  'Calle Sierpes, 10': 'Seville',
#  'Calle Sierpes, 11': 'Seville',
#  'Calle Sierpes, 12': 'Seville',
#  'Calle Sierpes, 13': 'Seville',
#  'Calle Sierpes, 14': 'Seville',
#  'Calle Sierpes, 15': 'Seville',
#  'Calle Sierpes, 16': 'Seville',
#  'Calle Sierpes, 17': 'Seville',
#  'Calle Sierpes, 18': 'Seville',
#  'Calle Sierpes, 19': 'Seville',
#  'Calle Sierpes, 20': 'Seville',
#  'Calle Sierpes, 21': 'Seville',
#  'Calle Sierpes, 22': 'Seville',
#  'Calle Sierpes, 23': 'Seville',
#  'Calle Sierpes, 24': 'Seville',
#  'Calle Sierpes, 25': 'Seville',
#  'Calle Sierpes, 26': 'Seville',
#  'Calle Sierpes, 27': 'Seville',
#  'Calle Sierpes, 28': 'Seville',
#  'Calle Sierpes, 29': 'Seville',
#  'Calle Sierpes, 30': 'Seville',
#  'Calle Sierpes, 31': 'Seville',
#  'Calle Sierpes, 32': 'Seville',
#  'Calle Sierpes, 33': 'Seville',
#  'Calle Sierpes, 34': 'Seville',
#  'Calle Sierpes, 35': 'Seville',
#  'Calle Sierpes, 36': 'Seville',
#  'Calle Sierpes, 37': 'Seville',
#  'Calle Sierpes, 38': 'Seville',
#  'Calle Sierpes, 39': 'Seville',
#  'Calle Sierpes, 40': 'Seville',
#  'Calle Sierpes, 41': 'Seville',
#  'Calle Sierpes, 42': 'Seville',
#  'Calle Sierpes, 43': 'Seville',
#  'Calle Sierpes, 44': 'Seville',
#  'Calle Sierpes, 45': 'Seville',
#  'Calle Sierpes, 46': 'Seville',
#  'Calle Sierpes, 47': 'Seville',
#  'Calle Sierpes, 48': 'Seville',
#  'Calle Sierpes, 49': 'Seville',
#  'Calle Sierpes, 50': 'Seville',
#  'Calle Sierpes, 51': 'Seville',
#  'Calle Sierpes, 52': 'Seville',
#  'Calle Sierpes, 53': 'Seville',
#  'Calle Sierpes, 54': 'Seville',
#  'Calle Sierpes, 55': 'Seville',
#  'Calle Sierpes, 56': 'Seville',
#  'Calle Sierpes, 57': 'Seville',
#  'Calle Sierpes, 58': 'Seville',
#  'Calle Sierpes, 59': 'Seville',
#  'Calle Sierpes, 60': 'Seville',
#  'Calle Sierpes, 61': 'Seville',
#  'Calle Sierpes, 62': 'Seville',
#  'Calle Sierpes, 63': 'Seville',
#  'Calle Sierpes, 64': 'Seville',
#  'Calle Sierpes, 65': 'Seville',
#  'Calle Sierpes, 66': 'Seville',
#  'Calle Sierpes, 67': 'Seville',
#  'Calle Sierpes, 68': 'Seville',
#  'Calle Sierpes, 69': 'Seville',
#  'Calle Sierpes, 70': 'Seville',
#  'Calle Sierpes, 71': 'Seville',
#  'Calle Sierpes, 72': 'Seville',
#  'Calle Sierpes, 73': 'Seville',
#  'Calle Sierpes, 74': 'Seville',
#  'Calle Sierpes, 75': 'Seville',
#  'Calle Sierpes, 76': 'Seville',
#  'Calle Sierpes, 77': 'Seville',
#  'Calle Sierpes, 78': 'Seville',
#  'Calle Sierpes, 79': 'Seville',
#  'Calle Sierpes, 80': 'Seville',
#  'Calle Sierpes, 81': 'Seville',
#  'Calle Sierpes, 82': 'Seville',
#  'Calle Sierpes, 83': 'Seville',
#  'Calle Sierpes, 84': 'Seville',
#  'Calle Sierpes, 85': 'Seville',
#  'Calle Sierpes, 86': 'Seville',
#  'Calle Sierpes, 87': 'Seville',
#  'Calle Sierpes, 88': 'Seville',
#  'Calle Sierpes, 89': 'Seville',
#  'Calle Sierpes, 90': 'Seville',
#  'Calle Sierpes, 91': 'Seville',
#  'Calle Sierpes, 92': 'Seville',
#  'Calle Sierpes, 93': 'Seville',
#  'Calle Sierpes, 94': 'Seville',
#  'Calle Sierpes, 95': 'Seville',
#  'Calle Sierpes, 96': 'Seville',
#  'Calle Sierpes, 97': 'Seville',
#  'Calle Sierpes, 98': 'Seville',
#  'Calle Sierpes, 99': 'Seville',
#  'Calle Sierpes, 100': 'Seville',
#  ...}

# %%
city_to_province = {
    "Jerez de la Frontera": "Cádiz",
    "Madrid": "Madrid",
    "Barcelona": "Barcelona",
    "Seville": "Seville",
    "Valencia": "Valencia",
    "Bilbao": "Biscay",
    "Malaga": "Malaga",
    "Zaragoza": "Zaragoza",
    "Murcia": "Murcia",
    "Palma": "Balearic Islands",
    "Paris": "Île-de-France",
    "Marseille": "Bouches-du-Rhône",
    "Lyon": "Auvergne-Rhône-Alpes",
    "Toulouse": "Occitanie",
    "Nice": "Provence-Alpes-Côte d'Azur",
    "Nantes": "Loire-Atlantique",
    "Strasbourg": "Bas-Rhin",
    "Montpellier": "Hérault",
    "Bordeaux": "Gironde",
    "Lille": "Nord",
    "London": "Greater London",
    "Manchester": "Greater Manchester",
    "Liverpool": "Merseyside",
    "Edinburgh": "City of Edinburgh",
    "Glasgow": "Glasgow City",
    "Birmingham": "West Midlands",
    "Leeds": "West Yorkshire",
    "Bristol": "Bristol",
    "Sheffield": "South Yorkshire",
    "Leicester": "Leicestershire",
    "Berlin": "Berlin",
    "Munich": "Bavaria",
    "Frankfurt": "Hesse",
    "Hamburg": "Hamburg",
    "Cologne": "North Rhine-Westphalia",
    "Stuttgart": "Baden-Württemberg",
    "Düsseldorf": "North Rhine-Westphalia",
    "Dortmund": "North Rhine-Westphalia",
    "Essen": "North Rhine-Westphalia",
    "Leipzig": "Saxony",
    "Rome": "Lazio",
    "Milan": "Lombardy",
    "Naples": "Campania",
    "Turin": "Piedmont",
    "Palermo": "Sicily",
    "Genoa": "Liguria",
    "Bologna": "Emilia-Romagna",
    "Florence": "Tuscany",
    "Bari": "Apulia",
    "Catania": "Sicily",
    "Dublin": "Dublin",
    "Cork": "Cork",
    "Limerick": "Limerick",
    "Galway": "Galway",
    "Waterford": "Waterford"
}

# %%
def remove_short_last_word(input_str):
    words = input_str.split()
    if words:
        last_word = words[-1]
        if len(last_word) <= 3:
            words.pop()
        return ' '.join(words)
    else:
        return input_str

# %%
# Función para generar ID de proveedor
def generate_provider_id(company_name, country):
    company_name = remove_short_last_word(company_name)
    # Obtener las iniciales del nombre de la compañía
    words = company_name.split()
    if len(words) >= 3:
        initials = words[0][0] + words[1][0] + words[2][0]
    elif len(words) == 2:
        initials = words[0][:2] + words[1][0]
    elif len(words) == 1:
        initials = words[0][:3]
    else:
        # En caso de que no haya palabras en el nombre
        initials = "XXX"

    # Generar los 3 números aleatorios
    random_digits = ''.join(random.choice('0123456789') for _ in range(3))

    # Mapear el código del país
    country_codes = {
        'Spain': 'SP',
        'France': 'FR',
        'Germany': 'GE',
        'Ireland': 'IR',
        'United Kingdom': 'UK',
        'Italy': 'IT',
    }
    country_code = country_codes.get(country, 'XX')  # 'XX' para países desconocidos

    # Combinar las partes para formar el ID de proveedor
    provider_id = f'prov{initials}{random_digits}{country_code}'

    return provider_id

# %%
def assign_location(row):
    country = row['country']
    city = random.choice([c for c, c_country in cities.items() if c_country == country])
    address = random.choice([a for a, a_city in addresses.items() if a_city == city])
    province = city_to_province.get(city, 'Sin Provincia')
    return pd.Series([address, city, province])

# %%
df = name_comp.copy()
df['ID_proveedor'] = df.apply(lambda row: generate_provider_id(row['company_name'], row['country']), axis=1)
df['Nombre'] = df['company_name']
df[['Dirección', 'Ciudad', 'Provincia']] = df.apply(assign_location, axis=1)
df = df.drop(['company_name', 'country'], axis=1)
df
# Out:
#       ID_proveedor                                       Nombre  \
# 0     provLMH694FR       LVMH Moët Hennessy - Louis Vuitton, SE
# 1     provL'O574FR                                   L'Oréal SA
# 2     provHeI770FR                     Hermès International SCA
# 3     provChD567FR                            Christian Dior SE
# 4     provTot544FR                             TotalEnergies SE
# ...            ...                                          ...
# 1053  provBOI772IR  Bank Of Ireland (Governor & Company Of The)
# 1054  provApp249IR                               Applegreen plc
# 1055  provMal086IR                             Mallinckrodt plc
# 1056  provGaG280IR                       Gambling.com Group Ltd
# 1057  provAbb048IR                                    Abbey plc
#
#                        Dirección      Ciudad      Provincia
# 0              Rue de Rivoli, 70       Paris  Île-de-France
# 1         Place de la Bourse, 79    Bordeaux        Gironde
# 2          Place du Capitole, 79    Toulouse      Occitanie
# 3          Avenue de l'Opéra, 93       Paris  Île-de-France
# 4     Rue des Grandes Arcades, 7  Strasbourg       Bas-Rhin
# ...                          ...         ...            ...
# 1053            Grand Parade, 79        Cork           Cork
# 1054        O'Connell Street, 41   Waterford      Waterford
# 1055          Patrick Street, 89        Cork           Cork
# 1056              Shop Street, 6      Galway         Galway
# 1057            Henry Street, 83    Limerick       Limerick
#
# [1058 rows x 5 columns]

# %%
# Out:
# provNdl690SP
